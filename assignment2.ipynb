# %%
edges = [('A','B'), ('A','C'), ('B','D'), ('C','D'), ('D','E'), ('E','F')]
nodes = ['A', 'B', 'C', 'D', 'E', 'F']
distances = {'A':0, 'B':0, 'C':0, 'D':0, 'E':0, 'F':0}
visited = []
from collections import deque
q = deque()
distanceAdder = 0
for node in nodes:
    q.clear()
    q.append(node)
    visited.clear()
    visited.append(node)
    distances = {key : 0 for key in distances}
    while (len(q) != 0):
        nodec = q.popleft()
        for i,j in edges:
            if i==nodec or j == nodec :
                if(i != nodec):
                    if(i in visited):
                        continue
                    distances[i] = distances[nodec] + 1
                    q.append(i)
                    visited.append(i)
                else:
                    if(j in visited):
                        continue
                    distances[j] = distances[nodec] + 1
                    q.append(j)
                    visited.append(j)
    for i in distances.values():
        distanceAdder += i

totalPairs = 15
distanceAdder /= 2
print(distanceAdder/totalPairs)
# Out:
# 1.9333333333333333

# %%
edges = [('A','B'), ('B','C'), ('C','D'), ('D','E'), ('C','F'), ('F','G')]
nodes = ['A', 'B', 'C', 'D', 'E', 'F']
distances = {'A':0, 'B':0, 'C':0, 'D':0, 'E':0, 'F':0}
visited = []
from collections import deque
q = deque()
maxDistance = 0
for node in nodes:
    q.clear()
    q.append(node)
    visited.clear()
    visited.append(node)
    distances = {key : 0 for key in distances}
    while (len(q) != 0):
        nodec = q.popleft()
        for i,j in edges:
            if i==nodec or j == nodec :
                if(i != nodec):
                    if(i in visited):
                        continue
                    distances[i] = distances[nodec] + 1
                    q.append(i)
                    visited.append(i)
                else:
                    if(j in visited):
                        continue
                    distances[j] = distances[nodec] + 1
                    q.append(j)
                    visited.append(j)
    for i in distances.values():
        if(i > maxDistance):
            maxDistance = i
        

print(maxDistance)
# Out:
# 4

# %%
nodes = 10
links = 18

possibleEdges = (nodes*(nodes-1))/2
print(possibleEdges)

density = (2*links)/(nodes*(nodes-1))
print(density)
# Out:
# 45.0
# 0.4
